# %% [markdown]
# ## 2020년도 쓰레기에 대한 환경오염 방지 노력
#   1. 적극적인 노력에 대한 평균

# %% [markdown]
# #### 데이터 출처
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN073R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN079R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN071R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN078R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN075R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN077R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   - https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN072R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   -https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN076R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do
#   -https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1SSEN074R&vw_cd=MT_TM2_TITLE&list_id=101_770605&scrId=&seqNo=&lang_mode=ko&obj_var_id=&itm_id=&conn_path=MT_TM2_TITLE&path=%252FeasyViewStatis%252FcustomStatisIndex.do

# %%
import numpy as np 
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import math
# %matplotlib inline

## 한글 폰트 적용 안되는 것에 대한 코드
matplotlib.rcParams['font.family'] ='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] =False

# %%
## 각 데이터셋 가져오기
df1 = pd.read_csv('환경오염_방지_노력__음식물_쓰레기_줄이기__13세_이상_인구.csv', encoding="CP949")
df2 = pd.read_csv('환경오염_방지_노력_가정_내_대기전력_줄이기__13세_이상_인구.csv', encoding="CP949")
df3 = pd.read_csv('환경오염_방지_노력_대중교통_이용하기__13세_이상_인구.csv', encoding="CP949")
df4 = pd.read_csv('환경오염_방지_노력_물_절약하기__13세_이상_인구.csv', encoding="CP949")
df5 = pd.read_csv('환경오염_방지_노력_일회용품_사용하지_않기__13세_이상_인구.csv', encoding="CP949")
df6 = pd.read_csv('환경오염_방지_노력_자연보호_및_환경보전활동_참여하기__13세_이상_인구.csv', encoding="CP949")
df7 = pd.read_csv('환경오염_방지_노력_재활용품_분리_배출하기__13세_이상_인구.csv', encoding="CP949")
df8 = pd.read_csv('환경오염_방지_노력_친환경제품_구입·사용하기__13세_이상_인구.csv', encoding="CP949")
df9 = pd.read_csv('환경오염_방지_노력_합성세제_사용_줄이기__13세_이상_인구.csv', encoding="CP949")

# %%
## 각각의 데이터셋에서 총계만 뽑기
df1Effort1 = df1.iloc[1]["2020.1"]
df2Effort1 = df2.iloc[1]["2020.1"]
df3Effort1 = df3.iloc[1]["2020.1"]
df4Effort1 = df4.iloc[1]["2020.1"]
df5Effort1 = df5.iloc[1]["2020.1"]
df6Effort1 = df6.iloc[1]["2020.1"]
df7Effort1 = df7.iloc[1]["2020.1"]
df8Effort1 = df8.iloc[1]["2020.1"]
df9Effort1 = df9.iloc[1]["2020.1"]

df1Effort2 = df1.iloc[1]["2020.2"]
df2Effort2 = df2.iloc[1]["2020.2"]
df3Effort2 = df3.iloc[1]["2020.2"]
df4Effort2 = df4.iloc[1]["2020.2"]
df5Effort2 = df5.iloc[1]["2020.2"]
df6Effort2 = df6.iloc[1]["2020.2"]
df7Effort2 = df7.iloc[1]["2020.2"]
df8Effort2 = df8.iloc[1]["2020.2"]
df9Effort2 = df9.iloc[1]["2020.2"]

df1Effort3 = df1.iloc[1]["2020.3"]
df2Effort3 = df2.iloc[1]["2020.3"]
df3Effort3 = df3.iloc[1]["2020.3"]
df4Effort3 = df4.iloc[1]["2020.3"]
df5Effort3 = df5.iloc[1]["2020.3"]
df6Effort3 = df6.iloc[1]["2020.3"]
df7Effort3 = df7.iloc[1]["2020.3"]
df8Effort3 = df8.iloc[1]["2020.3"]
df9Effort3 = df9.iloc[1]["2020.3"]

df1Effort4 = df1.iloc[1]["2020.4"]
df2Effort4 = df2.iloc[1]["2020.4"]
df3Effort4 = df3.iloc[1]["2020.4"]
df4Effort4 = df4.iloc[1]["2020.4"]
df5Effort4 = df5.iloc[1]["2020.4"]
df6Effort4 = df6.iloc[1]["2020.4"]
df7Effort4 = df7.iloc[1]["2020.4"]
df8Effort4 = df8.iloc[1]["2020.4"]
df9Effort4 = df9.iloc[1]["2020.4"]

# %%
## 하나의 array로 만들어주기
effortScore1 = [df1Effort1,df2Effort1,df3Effort1,df4Effort1,df5Effort1,df6Effort1,df7Effort1,df8Effort1,df9Effort1]
effortScore2 = [df1Effort2,df2Effort2,df3Effort2,df4Effort2,df5Effort2,df6Effort2,df7Effort2,df8Effort2,df9Effort2]
effortScore3 = [df1Effort3,df2Effort3,df3Effort3,df4Effort3,df5Effort3,df6Effort3,df7Effort3,df8Effort3,df9Effort3]
effortScore4 = [df1Effort4,df2Effort4,df3Effort4,df4Effort4,df5Effort4,df6Effort4,df7Effort4,df8Effort4,df9Effort4]
effortList = ["음식물쓰레기줄이기","가정내대기전력줄이기","대중교통이용하기","물절약하기","일회용품사용하지않기","자연보호및환경보전활동참여하기","재활용품분리배출하기","친환경제품구입·사용하기","합성세제사용줄이기"]

# %%
## numpy.array type으로 변경해주기
index = np.arange(9)
x = np.array(effortList)
## numpy.array type으로 변경해주면서 내용의 type은 float64로 변경
노력함 = np.array(effortScore1).astype(np.float64)
y2 = np.array(effortScore2).astype(np.float64)
y3 = np.array(effortScore3).astype(np.float64)
y4 = np.array(effortScore4).astype(np.float64)
노력안함 = y2+ y3 +y4

## 매우노력함평균값
total_avg1 = math.ceil(노력함.mean())

# %%
fig, ax = plt.subplots(figsize=(16,8))
bar_width = 0.2
# ax.bar(index,total_avg1,bar_width, alpha=0.4, color='blue', label='매우 노력함')
# ax.bar(index,total_avg3  + total_avg2 + total_avg4,bar_width, alpha=0.4, color='orange', label='보통 ~ 노력안함')
ax.bar(x,노력안함, alpha=0.6, color='red', label='보통 ~ 노력하지않음')
ax.bar(x,노력함, alpha=0.6, color='blue', label='매우 노력함')
ax.set_axisbelow(True)
ax.grid(True, axis='y')
# ax.axhline(y=total_avg,xmax=1,color="green",linestyle="dashed",label='평균')
plt.xticks(rotation=45)
ax.tick_params(axis = 'x', labelsize = 15)
ax.tick_params(axis = 'y', labelsize = 15)
ax.set_title("2020년 환경오염 방지 노력에 대한 설문", fontsize=20)
ax.set_xlabel("부문")
ax.set_ylabel("단위(%)")
fig.legend()
for i, v in enumerate(x):
        plt.text(v, 노력함[i], 노력함[i],   
                fontsize = 15, 
                color='blue',
                horizontalalignment='center',  
                verticalalignment='bottom')
        plt.text(v, 노력안함[i], 노력안함[i],   
                fontsize = 15, 
                color='blue',
                horizontalalignment='center',
                verticalalignment='bottom')
plt.show()
